# %% [markdown]
# Nhập 2 số thực a, b. Tìm nghiệm của phương trình bậc 1 ax + b = 0.

# %% [markdown]
# Bài làm

# %% [markdown]
# Nhập dữ liệu

# %%
a = int(input('Moi ban nhap he so a: '))
b = int(input('Moi ban nhap he so b: '))

# %% [markdown]
# Xử lý và xuất ra màn hình

# %%
s = f'Phuong trinh {a}x + {b} = 0'
if a == 0:
    if b == 0:
        print(f'{s} vo so nghiem')
    else:
        print(f'{s} vo nghiem')
else:
    x = -b / a
    print(f'{s} co nghiem x = {x}')
# Out:
# Phuong trinh 2x + 3 = 0 co nghiem x = -1.5
