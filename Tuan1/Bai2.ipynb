# %% [markdown]
# Chuyển đổi thời gian từ số giây sang giờ , số phút , số giây

# %% [markdown]
# Bài Làm

# %%
t = int(input("nhap vao tong so giay"))

# %% [markdown]
# Chuyển đổi sang giờ , phút , giây

# %%
hh=t//3600
mm=(t%3600)//60
ss=t%60

# %% [markdown]
# Xuất dữ liệu

# %%
print(f"{hh} gio {mm} phut {ss} giay")
# Out:
# 1 gio 1 phut 40 giay
